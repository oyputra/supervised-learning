# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\oktav\miniconda3\envs\jcopml\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
X = np.linspace(0, 10, 100)
y = np.sqrt(X)
y1 = np.sin(X)
y2 = np.cos(X)

# %% [markdown]
# # Inisialisasi Figure dan Axes

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure(figsize=(6, 6))
ax = plt.axes()
ax.plot(X, y)

# %%
fig = plt.figure(figsize=(6, 6))
ax = plt.axes()
ax.plot(X, y1)
ax.plot(X, y2)

# %% [markdown]
# ### shortcut

# %%
plt.figure(figsize=(6, 6))
plt.plot(X, y1, 'r-', linewidth=0.5)
plt.plot(X, y2, 'bo', markersize=3)
plt.xlim(0, 20)
plt.ylim(-2, 2)
plt.axis('equal')
plt.title("Sin dan Cos")
plt.xlabel("X")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
fig = plt.figure(figsize=(6, 6))
ax = plt.axes()

ax.plot(X, y1, 'r-', linewidth=0.5)
ax.plot(X, y2, 'bo', markersize=3)
ax.set_xlim(0, 20)
ax.set_ylim(-2, 2)
ax.set_title("Sin dan Cos", fontsize=14)
ax.set_xlabel("X", fontsize=10)
ax.set_ylabel("y", fontsize=10)
ax.axis('equal');

# %%
fig = plt.figure(figsize=(6, 6))
ax = plt.axes()

ax.plot(X, y1, 'r-', linewidth=0.5)
ax.plot(X, y2, 'bo', markersize=3)
ax.set(xlim=(0, 20), ylim=(-2, 2), title="Sin dan Cos", xlabel="X", ylabel="y")
ax.axis('equal');

# %%
fig = plt.figure(figsize=(6, 6))
ax = plt.axes()

ax.plot(X, y1, 'r-', linewidth=0.5, label='sin')
ax.plot(X, y2, 'bo', markersize=3, label='cos')
ax.set(xlim=(0, 20), ylim=(-2, 2), title="Sin dan Cos", xlabel="X", ylabel="y")
ax.axis('equal')
ax.legend(loc='lower center', ncol=2, shadow=True, borderpad=1)
